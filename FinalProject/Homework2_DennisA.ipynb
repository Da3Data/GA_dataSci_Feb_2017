# %% [markdown]
# # SYD DAT 7 - Visualisation and Regression
#
# ##Homework - Due March 13th, 2017
#
#
# * For the following use the github repository you made for your project.
# https://github.com/Da3Data/GA_dataSci_Feb_2017/tree/master/FinalProject
#
# * Load some data you have gathered for your project into Python.
# * Identify some numeric and categorical features in your data. Write this up in a file called README.md
# * Run some summary statistics over the numeric data.
# * Are there any interesting features of the data that jump out?
# * Generate some data visualisations that would be useful for you to explore your data set, particularly the numeric data right now.
#
# * If you can find any good candidates for a regression, try some regressors out.

# %%
# Load some data you have gathered for your project into Python.
# 3 files: users, movies, ratings
# all are of file type .dat

import pandas as pd

# %% [markdown]
# # Users.dat

# %%
usersDF = pd.read_table("C:\\Users\Dennis.shazadzai-tshba\\dataSets\\MovieLens_1mil\\data\\users.dat",
                       sep = "::",
                       header = None,
                       names = ['UserID', 'Gender', 'AgeRange', 'Occupation', 'ZipCode'],
                       engine = 'python')

# %%
help(pd.read_table)
# Out:
# Help on function read_table in module pandas.io.parsers:
#
# ...

# %%
usersDF.head()
# AgeRange and Occupation have a mapping to more descriptive values - in a later stage I will update both columns.
# e.g. AgeRange 1 = Under 18
# e.g. Occupation 15 = scientist
# Out:
#    UserID Gender  AgeRange  Occupation ZipCode
# 0       1      F         1          10   48067
# 1       2      M        56          16   70072
# 2       3      M        25          15   55117
# 3       4      M        45           7   02460
# 4       5      M        25          20   55455

# %% [markdown]
# # Movies.dat

# %%
moviesDF = pd.read_table("C:\\Users\Dennis.shazadzai-tshba\\dataSets\\MovieLens_1mil\\data\\movies.dat",
                       sep = "::",
                       header = None,
                       names = ['MovieID', 'Title', 'Genres'],
                       engine = 'python')

# %%
moviesDF.head()
# Out:
#    MovieID                               Title                        Genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# # Ratings.dat

# %%
ratingsDF = pd.read_table("C:\\Users\Dennis.shazadzai-tshba\\dataSets\\MovieLens_1mil\\data\\ratings.dat",
                       sep = "::",
                       header = None,
                       names = ['UserID', 'MovieID', 'Rating', 'TimeStamp'],
                       engine = 'python')

# %%
ratingsDF.head()
# ratings are 1 to 5 with 5 being the best
# Out:
#    UserID  MovieID  Rating  TimeStamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
# Identify some numeric and categorical features in your data. Write this up in a file called README.md 
# numeric = rating
# categorical = run .unique() to see dTypes and categories

moviesDF.Genres.unique()
# Out:
# array(["Animation|Children's|Comedy", "Adventure|Children's|Fantasy",
#        'Comedy|Romance', 'Comedy|Drama', 'Comedy', 'Action|Crime|Thriller',
#        "Adventure|Children's", 'Action', 'Action|Adventure|Thriller',
#        'Comedy|Drama|Romance', 'Comedy|Horror', "Animation|Children's",
#        'Drama', 'Action|Adventure|Romance', 'Drama|Thriller',
#        'Drama|Romance', 'Thriller', 'Action|Comedy|Drama',
#        'Crime|Drama|Thriller', 'Drama|Sci-Fi', 'Romance',
#        'Adventure|Sci-Fi', 'Adventure|Romance', "Children's|Comedy|Drama",
#        'Documentary', 'Drama|War', 'Action|Crime|Drama',
#        'Action|Adventure', 'Crime|Thriller',
#        "Animation|Children's|Musical|Romance", 'Action|Drama|Thriller',
#        "Children's|Comedy", 'Drama|Mystery', 'Sci-Fi|Thriller',
#        'Action|Comedy|Crime|Horror|Thriller', 'Drama|Musical',
#        'Crime|Drama|Romance', 'Adventure|Drama', 'Action|Thriller',
# ...

# %%
# Run some summary statistics over the numeric data.
# describe() get mean, counts etc, 

usersDF.describe()
# 6040 users
# avg ageRange of a user is in their 30s

# moviesDF.describe()

# ratingsDF.describe()
# Out:
#             UserID     AgeRange   Occupation
# count  6040.000000  6040.000000  6040.000000
# mean   3020.500000    30.639238     8.146854
# std    1743.742145    12.895962     6.329511
# min       1.000000     1.000000     0.000000
# 25%    1510.750000    25.000000     3.000000
# 50%    3020.500000    25.000000     7.000000
# 75%    4530.250000    35.000000    14.000000
# max    6040.000000    56.000000    20.000000

# %%
# Are there any interesting features of the data that jump out?
# I will be checking correlations and relationships between age, gender and occupation 
# to see what kind of movies the users in those 3 categories prefer based on genre

# %%
# Generate some data visualisations that would be useful for you to explore your data set, particularly the numeric data right now.
# histogram showing counts of ratings
# histogram showing counts of gender then age then occupations of users
# scatter: gender vs AgeRange

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# plt.plot(usersDF.AgeRange, usersDF.UserID)

plt.scatter(usersDF.UserID, usersDF.AgeRange)

# NOTE: will look into summarising the data in order to produce more valuable visuals

# %%
usersDF.head()
# Out:
#    UserID Gender  AgeRange  Occupation ZipCode
# 0       1      F         1          10   48067
# 1       2      M        56          16   70072
# 2       3      M        25          15   55117
# 3       4      M        45           7   02460
# 4       5      M        25          20   55455

# %%
# * If you can find any good candidates for a regression, try some regressors out.
